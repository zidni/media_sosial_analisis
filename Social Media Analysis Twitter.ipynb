# %% [markdown]
# Query by keyword in Twitter

# %%
# General:
import tweepy           # To consume Twitter's API
import pandas as pd     # To handle data
import numpy as np      # For number computing

# For plotting and visualization:
from IPython.display import display
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

from textblob import TextBlob
import re

# Twitter App access keys 

def twitter_setup():
    """
    Utility function to setup the Twitter's API
    with our access keys provided.
    """
    # Authentication and access using keys:

    # Consume:
    CONSUMER_KEY    = 'pMJ2au52K4CZfoNdEyE2X8taN'
    CONSUMER_SECRET = 'yeXIq7g9YPZQ5CFerPSmKcaQwS5RuNH6jWuj28iXqnOQzVeSri'

    # Access:
    ACCESS_TOKEN  = '45675265-qacI7qadnG6ZVrMsqUCtaojNjAUnsigUh8tb3n4wn'
    ACCESS_SECRET = 'sIoWBa6xorM1D8kbiOBInkto5734YrikwsdVPhIQGlPbh'
    
    auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
    auth.set_access_token(ACCESS_TOKEN, ACCESS_SECRET)

    # Return API with authentication:
    api = tweepy.API(auth)
    
    return api
   
    
# We create an extractor object:
twitapi = twitter_setup()

tweets = []

fetched_tweets = twitapi.search(q = "@aniesbaswedan", count = 200)
 
# parsing tweets one by one
for tweet in fetched_tweets:
    # empty dictionary to store required params of a tweet
    parsed_tweet = {}

    # saving text of tweet
    parsed_tweet['text'] = tweet.text

    # appending parsed tweet to tweets list
    if tweet.retweet_count > 0:
        # if tweet has retweets, ensure that it is appended only once
        if parsed_tweet not in tweets:
            tweets.append(parsed_tweet)
    else:
        tweets.append(parsed_tweet)
 

print("Number of tweets extracted: {}.\n".format(len(tweets)))

# We print the most recent 5 tweets:
print("5 recent tweets:\n")
for tweet in tweets[:5]:
    print(tweet['text'])
    print()  
    
    
# We create a pandas dataframe as follows:
data = pd.DataFrame(data=[tweet['text'] for tweet in tweets], columns=['Tweets'])

# Display of first 10 elements from dataframe:
display(data.head(10))


def clean_tweet(tweet):
    '''
    Utility function to clean the text in a tweet by removing 
    links and special characters using regex.
    '''
    return ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)", " ", tweet).split())

def analize_sentiment(tweet):
    '''
    Utility function to classify the polarity of a tweet
    using textblob.
    '''
    analysis = TextBlob(clean_tweet(tweet))
    if analysis.sentiment.polarity > 0:
        return 1
    elif analysis.sentiment.polarity == 0:
        return 0
    else:
        return -1
    
    
# We create a column with the result of the analysis:
data['SA'] = np.array([ analize_sentiment(tweet) for tweet in data['Tweets'] ])

# We display the updated dataframe with the new column:
display(data.head(10))

# We construct lists with classified tweets:

pos_tweets = [ tweet for index, tweet in enumerate(data['Tweets']) if data['SA'][index] > 0]
neu_tweets = [ tweet for index, tweet in enumerate(data['Tweets']) if data['SA'][index] == 0]
neg_tweets = [ tweet for index, tweet in enumerate(data['Tweets']) if data['SA'][index] < 0]


# We print percentages:

print("Percentage of positive tweets: {}%".format(len(pos_tweets)*100/len(data['Tweets'])))
print("Percentage of neutral tweets: {}%".format(len(neu_tweets)*100/len(data['Tweets'])))
print("Percentage de negative tweets: {}%".format(len(neg_tweets)*100/len(data['Tweets'])))
# Out:
# Number of tweets extracted: 77.
#
# 5 recent tweets:
#
# angkut hasil kuras sal jl masjid kbn jeruk kel maphar kec tamansari
# @aniesbaswedan
# @sandiuno
# @TeguhHendarwan… https://t.co/rbhzt31sQw
#
# Pengerjaan terase di mangga besar 13 RW.04  jakarta pusat.
# @aniesbaswedan
# @sandiuno
# @TeguhHendarwan… https://t.co/2SZfhaEBZt
#
# Loh bgm ini @aniesbaswedan @SuaraAnies @pandji .....😕 https://t.co/Ew0txZi7xA
#
# RT @PartaiSocmed: Betapapun kita harus ucapkan selamat atas prestasi pak @aniesbaswedan dan pak @sandiuno.
# Dan untuk @SuaraAnies silakan b…
#
# @GunRomli Sampah cina tu klu sampah pribumi bukan begitu..tnya aja @aniesbaswedan @sandiuno
#                                               Tweets
# 0  angkut hasil kuras sal jl masjid kbn jeruk kel...
# 1  Pengerjaan terase di mangga besar 13 RW.04  ja...
# 2  Loh bgm ini @aniesbaswedan @SuaraAnies @pandji...
# 3  RT @PartaiSocmed: Betapapun kita harus ucapkan...
# 4  @GunRomli Sampah cina tu klu sampah pribumi bu...
# 5  @Djat_mika @don_rahmad @DesaKita2 @irwank2k2 @...
# 6  Monitoring pengecatan Site file Danau Sunter S...
# 7  @aniesbaswedan @sandiuno @DKIJakarta @InfokomJ...
# 8  @Bolalob INI GIMANA PAK? @sandiuno @aniesbaswedan
# 9  RT @JTanjungBarat: JAKarta itu setia, setia sa...
#                                               Tweets  SA
# 0  angkut hasil kuras sal jl masjid kbn jeruk kel...   0
# 1  Pengerjaan terase di mangga besar 13 RW.04  ja...   0
# 2  Loh bgm ini @aniesbaswedan @SuaraAnies @pandji...   0
# 3  RT @PartaiSocmed: Betapapun kita harus ucapkan...   0
# 4  @GunRomli Sampah cina tu klu sampah pribumi bu...   0
# 5  @Djat_mika @don_rahmad @DesaKita2 @irwank2k2 @...   0
# 6  Monitoring pengecatan Site file Danau Sunter S...   0
# 7  @aniesbaswedan @sandiuno @DKIJakarta @InfokomJ...   0
# 8  @Bolalob INI GIMANA PAK? @sandiuno @aniesbaswedan   0
# 9  RT @JTanjungBarat: JAKarta itu setia, setia sa...   0
# Percentage of positive tweets: 1.2987012987012987%
# Percentage of neutral tweets: 96.1038961038961%
# Percentage de negative tweets: 2.5974025974025974%
